# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.5.5.64-cp37-abi3-macosx_11_0_arm64.whl (29.9 MB)
# Requirement already satisfied: numpy>=1.21.2 in /Users/davidrestrepo/miniforge3/envs/object_detection_test/lib/python3.9/site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.64

# %%
# get the reference to the webcam
import cv2

# %% [markdown]
# # get the reference to the webcam

# %%
camera = cv2.VideoCapture(0)
imagesList = []


while(True):
   
    _, frame = camera.read()
    
    cv2.imshow("Camera", frame)

    key = cv2.waitKey(1)

    if key & 0xFF == ord("q"):
        break
    elif key & 0xFF == ord("1"):
        imagesList.append(frame)
        print('frame saved')

camera.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Save the Images

# %%
for i, img in enumerate(imagesList):
    
    image = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

    image = cv2.resize(image, (224, 224))
    
    cv2.imwrite('./images/{}.png'.format(i), cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
